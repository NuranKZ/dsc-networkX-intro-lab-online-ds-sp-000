# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#Import-the-Data" data-toc-modified-id="Import-the-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Import the Data</a></span></li><li><span><a href="#Creating-a-Graph" data-toc-modified-id="Creating-a-Graph-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creating a Graph</a></span></li><li><span><a href="#Adding-Nodes" data-toc-modified-id="Adding-Nodes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Adding Nodes</a></span></li><li><span><a href="#Adding-Edges" data-toc-modified-id="Adding-Edges-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Adding Edges</a></span></li><li><span><a href="#Visualizing-the-Graph" data-toc-modified-id="Visualizing-the-Graph-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Visualizing the Graph</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Summary</a></span></li></ul></div>

# %% [markdown]
# # NetworkX Introduction - Lab
#
# ## Introduction
#
# In this lab, you'll practice some of the introductory skills for NetworkX introduced in the previous lesson.
# To do this, you'll create a graph to visualize users and businesses from yelp reviews.
# ## Objectives
#
# You will be able to:
# * Create basic network graphs using NetworkX
# * Add nodes to network graphs with NetworkX
# * Add edges to network graphs with NetworkX
# * Visualize network graphs with NetworkX

# %% [markdown]
# ## Import the Data
#
# To start, import the data stored in the file 'Yelp_reviews.csv'

# %%
#Your code here
import pandas as pd
df = pd.read_csv('Yelp_reviews.csv')
df.head()
df.nunique()
# Out:
# business_id    12
# date           73
# review_id      76
# stars           5
# text           76
# type            1
# user_id        63
# cool            7
# useful          8
# funny           8
# dtype: int64

# %% [markdown]
# ## Creating a Graph
#
# Now, create an initial graph!

# %%
#Your code here
import networkx as nx
G = nx.Graph()

# %% [markdown]
# ## Adding Nodes

# %% [markdown]
# Create a node for each user and each business in the dataset. Networks with multiple node types like this are called **bimodal networks**.
#
# Optionally, go further by creating a list of colors for when you visualize the graph. If you do this, append the color "green" to your color list every time you add a user node and append the color "blue" to your color list every time you add a business node.

# %%
#Your code here
names = {}
node_color = []
for n, person in enumerate(df.user_id.unique()):
    name = "User{}".format(n)
    names[person] = name
    G.add_node(name)
    node_color.append("green")
for n, biz in enumerate(df.business_id.unique()):
    name = "Business{}".format(n)
    names[biz] = name
    G.add_node(name)
    node_color.append("blue")

# %% [markdown]
# ## Adding Edges
#
# Next, iterate through the dataset and create an edge between users and the businesses they have reviewed.

# %%
#Your code here
for row in df.index:
    user = df['user_id'][row]
    u_name = names[user]
    biz = df['business_id'][row]
    b_name = names[biz]
    G.add_edge(u_name, b_name)

# %% [markdown]
# ## Visualizing the Graph
#
# Finally, create a visualization of your network. If you chose to color your nodes, pass the list of colors through the optional `node_color` parameter.

# %%
#Your code here
# %matplotlib inline
nx.draw(G, with_labels=True, alpha=.7, font_size=6, node_size=500, node_color=node_color)
# Out:
# C:\Users\ww\AppData\Local\conda\conda\envs\learn-env\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# ## Summary
#
# Nice work! In this lab you created an initial network to visualize a bimodal network of businesses and yelp reviewers!
